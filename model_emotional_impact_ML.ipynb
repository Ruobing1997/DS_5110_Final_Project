# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (2.2.1)
# Requirement already satisfied: scipy<2,>=1.10.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (1.15.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (3.5.0)

# %%
pip install shap imbalanced-learn
# Out:
# Requirement already satisfied: shap in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (0.47.1)
# Requirement already satisfied: imbalanced-learn in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (0.13.0)
# Requirement already satisfied: numpy in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (2.2.1)
# Requirement already satisfied: scipy in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (1.15.1)
# Requirement already satisfied: scikit-learn in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (0.61.2)
# Requirement already satisfied: cloudpickle in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from shap) (4.13.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from numba>=0.54->shap) (0.44.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/yiqingma/miniconda3/envs/DS5110/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from imblearn.over_sampling import SMOTE
from scipy.sparse import hstack
import shap
import os

# Load dataset
df = pd.read_csv("cleaned_data/final/BERT/all_merged_labeled_contextual.csv")

# Drop NA values
target = 'emotional_impact_ML'
text_col = 'assault_desc'
struct_features = ['victim_profession', 'department', 'perpetrator_type', 'violence_type', 'emotional_impact', 'response_action']
df = df.dropna(subset=struct_features + [target, text_col])

# Encode target
y = LabelEncoder().fit_transform(df[target])

# Feature engineering
X_struct = pd.get_dummies(df[struct_features])
tfidf = TfidfVectorizer(max_features=300, stop_words='english')
X_text = tfidf.fit_transform(df[text_col])

# Combine features
X_combined = hstack([X_struct, X_text])
X_combined = StandardScaler(with_mean=False).fit_transform(X_combined)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, random_state=42)

# SMOTE
smote = SMOTE(random_state=42)
X_train_res, y_train_res = smote.fit_resample(X_train, y_train)

# Model training
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC()
}

# Evaluation and save confusion matrices
labels = sorted(df[target].unique())
os.makedirs("cleaned_data/final/imgs", exist_ok=True)

model_scores = {}

for name, model in models.items():
    model.fit(X_train_res, y_train_res)
    y_pred = model.predict(X_test)

    report = classification_report(y_test, y_pred, target_names=labels, output_dict=True)
    model_scores[name] = report["weighted avg"]

    print(f"\n{name} - Classification Report")
    print(classification_report(y_test, y_pred, target_names=labels))

    cm = confusion_matrix(y_test, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap="Blues")
    plt.title(f"{name} - emotional_impact_ML Classification")
    plt.savefig(f"cleaned_data/final/imgs/{name.replace(' ', '_').lower()}_cm.png", bbox_inches='tight')
    plt.close()

# Feature Importance (Random Forest only)
if "Random Forest" in models:
    rf_model = models["Random Forest"]
    feature_names = list(X_struct.columns) + list(tfidf.get_feature_names_out())
    importances = rf_model.feature_importances_
    indices = np.argsort(importances)[-10:][::-1]  # top 10

    plt.figure(figsize=(10, 6))
    sns.barplot(x=importances[indices], y=np.array(feature_names)[indices])
    plt.title("Top 10 Feature Importances (Random Forest)")
    plt.tight_layout()
    plt.savefig("cleaned_data/final/imgs/rf_feature_importance.png")
    plt.close()

# SHAP Explanation (Random Forest)
X_train_dense = X_train_res.toarray()
X_test_dense = X_test[:100].toarray()
explainer = shap.Explainer(rf_model, X_train_dense)
shap_values = explainer(X_test_dense)

shap.summary_plot(shap_values, X_test_dense, feature_names=feature_names, max_display=10, show=False)
plt.title("SHAP Summary - Random Forest")
plt.savefig("cleaned_data/final/imgs/shap_summary.png", bbox_inches='tight')
plt.close()

# Compare models summary
print("\n\n📊 Model Comparison Summary (Weighted F1-score, Precision, Recall):")
for model, metrics in model_scores.items():
    print(f"{model}: F1={metrics['f1-score']:.2f}, Precision={metrics['precision']:.2f}, Recall={metrics['recall']:.2f}")

# KMeans Clustering + PCA
cluster_cols = ['victim_profession', 'department', 'violence_type']
cluster_df = df.dropna(subset=cluster_cols)
X_cluster = pd.get_dummies(cluster_df[cluster_cols])

pca = PCA(n_components=2, random_state=42)
X_pca = pca.fit_transform(X_cluster)

kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)
clusters = kmeans.fit_predict(X_cluster)

pca_df = pd.DataFrame(X_pca, columns=["PC1", "PC2"])
pca_df["Cluster"] = clusters

plt.figure(figsize=(8, 6))
sns.scatterplot(data=pca_df, x="PC1", y="PC2", hue="Cluster", palette="Set2")
plt.title("KMeans Clustering of Roles & Violence Types (PCA 2D)")
plt.tight_layout()
plt.savefig("cleaned_data/final/imgs/kmeans_pca_roles.png")
plt.close()

# Cluster summaries
cluster_df['Cluster'] = clusters
for col in cluster_cols:
    print(f"\nTop 3 '{col}' per Cluster:")
    print(cluster_df.groupby('Cluster')[col].value_counts().groupby(level=0).nlargest(3))
# Out:
# Logistic Regression - Classification Report
#               precision    recall  f1-score   support
#
#         Mild       0.53      0.39      0.45        23
#     Moderate       0.81      0.77      0.79       155
#       Severe       0.43      0.53      0.47        51
#
#     accuracy                           0.68       229
#    macro avg       0.59      0.56      0.57       229
# weighted avg       0.69      0.68      0.69       229
#
#
# Random Forest - Classification Report
#               precision    recall  f1-score   support
#
#         Mild       0.71      0.52      0.60        23
#     Moderate       0.88      0.81      0.84       155
#       Severe       0.47      0.65      0.55        51
#
#     accuracy                           0.74       229
#    macro avg       0.69      0.66      0.66       229
# weighted avg       0.77      0.74      0.75       229
#
#
# SVM - Classification Report
#               precision    recall  f1-score   support
#
#         Mild       0.78      0.30      0.44        23
#     Moderate       0.76      0.86      0.81       155
#       Severe       0.45      0.39      0.42        51
#
#     accuracy                           0.70       229
#    macro avg       0.66      0.52      0.56       229
# weighted avg       0.69      0.70      0.69       229
#
#
#
# 📊 Model Comparison Summary (Weighted F1-score, Precision, Recall):
# Logistic Regression: F1=0.69, Precision=0.69, Recall=0.68
# Random Forest: F1=0.75, Precision=0.77, Recall=0.74
# SVM: F1=0.69, Precision=0.69, Recall=0.70
#
# Top 3 'victim_profession' per Cluster:
# Cluster  Cluster  victim_profession
# 0        0        other                239
#                   nurse                 79
#                   security              23
# 1        1        nurse                247
#                   tech                 140
#                   security              79
# 2        2        other                284
# Name: count, dtype: int64
#
# Top 3 'department' per Cluster:
# Cluster  Cluster  department
# 0        0        other                   193
#                   emergency department     38
#                   Emergency Department     36
# 1        1        emergency department    113
#                   katahdin 2 south         93
#                   other                    32
# 2        2        other                    85
#                   Emergency Department     51
#                   bc                       42
# Name: count, dtype: int64
#
# Top 3 'violence_type' per Cluster:
# Cluster  Cluster  violence_type
# 0        0        verbal           380
#                   other              1
# 1        1        physical         433
#                   both              21
#                   other             16
# 2        2        physical         238
#                   other             40
#                   threat             6
# Name: count, dtype: int64
